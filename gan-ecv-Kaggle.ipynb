# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/image-colorization-dataset/data/test_color/image5500.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5639.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5275.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5321.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5354.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5000.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5226.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5267.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5040.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5148.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5550.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5323.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5342.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5157.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5383.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5068.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5670.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5243.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5271.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5642.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5603.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5195.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5621.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5351.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5492.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5677.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5489.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5513.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5108.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5360.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5552.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5141.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5350.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5344.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5622.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5290.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5507.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5471.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5136.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5490.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5160.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5528.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5737.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5295.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5598.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5449.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5076.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5401.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5178.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5408.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5177.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5567.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5021.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5064.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5458.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5346.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5508.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5464.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5193.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5538.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5291.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5457.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5572.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5281.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5355.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5593.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5617.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5468.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5694.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5127.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5395.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5591.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5372.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5402.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5236.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5143.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5626.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5256.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5525.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5571.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5705.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5158.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5376.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5065.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5411.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5247.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5100.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5534.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5434.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5121.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5058.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5701.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5050.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5094.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5678.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5098.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5412.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5307.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5118.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5209.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5627.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5527.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5547.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5583.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5406.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5347.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5584.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5024.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5478.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5634.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5643.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5652.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5006.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5015.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5453.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5111.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5398.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5722.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5385.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5296.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5060.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5504.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5038.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5428.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5203.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5619.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5314.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5032.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5162.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5682.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5501.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5533.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5002.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5365.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5026.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5318.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5651.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5687.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5611.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5268.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5013.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5616.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5292.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5608.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5445.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5175.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5084.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5056.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5049.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5590.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5220.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5491.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5315.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5494.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5134.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5729.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5232.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5120.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5730.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5343.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5289.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5661.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5663.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5258.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5486.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5239.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5130.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5048.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5465.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5070.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5521.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5047.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5009.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5641.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5017.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5530.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5234.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5263.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5320.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5359.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5266.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5152.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5356.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5481.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5420.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5614.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5606.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5537.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5437.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5479.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5380.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5655.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5403.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5317.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5213.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5339.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5206.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5721.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5301.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5204.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5348.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5417.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5561.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5014.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5257.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5638.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5147.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5562.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5536.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5709.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5025.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5410.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5011.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5151.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5736.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5735.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5539.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5251.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5393.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5474.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5328.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5447.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5253.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5069.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5196.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5522.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5018.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5719.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5659.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5555.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5122.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5053.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5496.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5690.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5592.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5727.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5034.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5187.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5442.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5287.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5202.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5581.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5325.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5604.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5072.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5429.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5163.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5691.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5610.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5261.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5511.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5022.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5674.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5140.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5620.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5413.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5189.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5657.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5105.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5215.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5210.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5090.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5106.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5174.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5159.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5515.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5569.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5233.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5407.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5306.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5003.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5043.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5142.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5212.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5680.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5331.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5176.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5199.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5443.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5338.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5184.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5563.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5168.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5300.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5589.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5575.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5030.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5097.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5392.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5455.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5362.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5441.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5460.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5330.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5332.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5689.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5126.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5250.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5673.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5700.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5260.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5707.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5192.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5421.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5082.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5313.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5625.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5541.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5366.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5161.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5227.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5237.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5205.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5715.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5560.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5379.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5308.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5191.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5132.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5665.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5519.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5384.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5671.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5636.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5067.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5242.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5087.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5506.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5145.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5480.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5586.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5016.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5720.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5352.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5214.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5676.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5062.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5650.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5044.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5117.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5646.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5046.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5088.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5224.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5546.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5544.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5518.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5409.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5288.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5285.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5096.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5337.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5556.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5165.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5027.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5653.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5535.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5077.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5345.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5238.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5170.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5368.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5341.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5336.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5131.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5001.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5681.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5109.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5679.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5316.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5051.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5185.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5115.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5485.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5382.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5405.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5133.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5476.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5558.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5423.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5309.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5564.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5667.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5415.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5073.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5637.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5155.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5446.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5602.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5574.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5255.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5693.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5658.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5377.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5484.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5683.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5326.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5080.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5738.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5688.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5467.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5526.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5532.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5543.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5273.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5597.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5188.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5358.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5444.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5601.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5473.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5110.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5353.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5007.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5400.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5426.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5228.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5577.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5036.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5549.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5035.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5280.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5568.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5725.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5218.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5509.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5712.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5542.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5135.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5732.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5093.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5684.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5394.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5319.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5091.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5654.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5524.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5340.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5647.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5311.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5085.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5389.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5041.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5374.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5327.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5262.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5433.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5594.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5566.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5613.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5031.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5390.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5335.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5553.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5559.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5675.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5548.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5472.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5497.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5075.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5386.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5246.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5194.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5367.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5431.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5523.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5063.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5662.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5462.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5733.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5666.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5470.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5635.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5450.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5656.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5404.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5286.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5618.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5397.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5037.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5488.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5279.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5095.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5107.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5086.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5146.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5514.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5222.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5399.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5495.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5633.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5219.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5225.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5456.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5459.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5728.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5113.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5695.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5179.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5640.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5272.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5283.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5436.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5570.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5112.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5660.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5686.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5074.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5333.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5726.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5172.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5630.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5600.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5578.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5119.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5370.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5020.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5329.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5324.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5422.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5454.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5439.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5469.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5083.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5123.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5173.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5599.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5276.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5270.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5648.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5718.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5294.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5071.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5129.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5166.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5702.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5557.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5201.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5502.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5731.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5361.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5692.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5696.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5713.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5710.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5303.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5164.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5505.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5582.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5223.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5334.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5150.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5668.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5698.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5615.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5277.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5181.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5282.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5381.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5375.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5081.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5363.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5551.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5624.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5180.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5461.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5540.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5493.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5241.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5254.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5207.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5252.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5297.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5595.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5004.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5612.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5182.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5717.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5023.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5438.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5042.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5249.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5697.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5208.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5293.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5055.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5169.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5554.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5664.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5416.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5369.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5028.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5529.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5154.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5244.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5516.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5183.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5487.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5373.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5099.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5052.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5520.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5723.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5685.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5517.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5451.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5302.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5448.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5432.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5425.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5139.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5102.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5440.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5482.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5512.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5579.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5391.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5211.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5221.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5010.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5587.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5418.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5545.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5190.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5312.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5278.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5114.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5104.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5125.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5265.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5672.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5466.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5264.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5299.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5573.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5217.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5137.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5304.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5588.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5531.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5101.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5724.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5089.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5644.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5623.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5116.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5008.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5452.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5156.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5167.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5245.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5066.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5510.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5186.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5057.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5200.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5427.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5503.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5149.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5475.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5387.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5310.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5388.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5649.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5629.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5669.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5078.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5706.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5005.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5138.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5231.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5230.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5029.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5632.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5645.jpg
# /kaggle/input/image-colorization-dataset/data/test_color/image5565.jpg
# ...
# /kaggle/input/image-colorization-dataset/data/test_black/image5119.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5370.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5020.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5329.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5324.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5422.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5454.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5439.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5469.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5083.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5123.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5173.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5599.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5276.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5270.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5648.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5718.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5294.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5071.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5129.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5166.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5702.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5557.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5201.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5502.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5731.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5361.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5692.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5696.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5713.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5710.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5303.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5164.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5505.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5582.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5223.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5334.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5150.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5668.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5698.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5615.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5277.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5181.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5282.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5381.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5375.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5081.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5363.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5551.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5624.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5180.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5461.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5540.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5493.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5241.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5254.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5207.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5252.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5297.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5595.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5004.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5612.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5182.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5717.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5023.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5438.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5042.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5249.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5697.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5208.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5293.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5055.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5169.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5554.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5664.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5416.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5369.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5028.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5529.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5154.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5244.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5516.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5183.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5487.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5373.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5099.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5052.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5520.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5723.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5685.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5517.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5451.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5302.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5448.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5432.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5425.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5139.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5102.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5440.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5482.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5512.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5579.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5391.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5211.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5221.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5010.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5587.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5418.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5545.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5190.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5312.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5278.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5114.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5104.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5125.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5265.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5672.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5466.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5264.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5299.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5573.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5217.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5137.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5304.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5588.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5531.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5101.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5724.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5089.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5644.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5623.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5116.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5008.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5452.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5156.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5167.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5245.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5066.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5510.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5186.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5057.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5200.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5427.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5503.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5149.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5475.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5387.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5310.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5388.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5649.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5629.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5669.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5078.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5706.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5005.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5138.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5231.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5230.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5029.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5632.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5645.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5565.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5631.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5216.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5259.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5605.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5419.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5609.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5240.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5153.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5699.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5322.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5061.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5269.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5607.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5092.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5483.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5274.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5371.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5197.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5424.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5596.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5463.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5357.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5235.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5430.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5124.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5284.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5128.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5734.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5477.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5045.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5229.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5711.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5585.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5033.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5704.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5716.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5628.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5079.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5580.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5396.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5364.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5499.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5171.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5378.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5103.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5435.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5414.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5012.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5498.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5714.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5019.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5144.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5305.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5248.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5576.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5059.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5349.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5708.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5039.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5054.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5298.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5198.jpg
# /kaggle/input/image-colorization-dataset/data/test_black/image5703.jpg

# %%
import glob
import random
import os
import numpy as np

import torch
from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as transforms
from torch import nn
from matplotlib import pyplot as plt

#from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM

import argparse
import os
import numpy as np
import math
import itertools
import sys

import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid

from torch.utils.data import DataLoader
from torch.autograd import Variable

#from models import *
#from datasets import *

import torch.nn as nn
import torch.nn.functional as F
import torch


from torchvision.models import vgg19

from skimage import color
from IPython import embed

# %% [markdown]
# # Models
# ## Discriminator

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        vgg19_model = vgg19(pretrained=True)
        self.feature_extractor = nn.Sequential(*list(vgg19_model.features.children())[:18])

    def forward(self, img):
        return self.feature_extractor(img)

class Discriminator(nn.Module):
    def __init__(self, input_shape):
        super(Discriminator, self).__init__()

        self.input_shape = input_shape
        in_channels, in_height, in_width = self.input_shape
        patch_h, patch_w = int(in_height / 2 ** 4), int(in_width / 2 ** 4)
        self.output_shape = (1, patch_h, patch_w)

        def discriminator_block(in_filters, out_filters, first_block=False):
            layers = []
            layers.append(nn.Conv2d(in_filters, out_filters, kernel_size=3, stride=1, padding=1))
            if not first_block:
                layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            layers.append(nn.Conv2d(out_filters, out_filters, kernel_size=3, stride=2, padding=1))
            layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        layers = []
        in_filters = in_channels
        for i, out_filters in enumerate([64, 128, 256, 512]):
            layers.extend(discriminator_block(in_filters, out_filters, first_block=(i == 0)))
            in_filters = out_filters

        layers.append(nn.Conv2d(out_filters, 1, kernel_size=3, stride=1, padding=1))

        self.model = nn.Sequential(*layers)

    def forward(self, img):
        return self.model(img)

# %% [markdown]
# ## ECV16

# %%
class BaseColor(nn.Module):
	def __init__(self):
		super(BaseColor, self).__init__()

		self.l_cent = 50.
		self.l_norm = 100.
		self.ab_norm = 110.

	def normalize_l(self, in_l):
		return (in_l-self.l_cent)/self.l_norm

	def unnormalize_l(self, in_l):
		return in_l*self.l_norm + self.l_cent

	def normalize_ab(self, in_ab):
		return in_ab/self.ab_norm

	def unnormalize_ab(self, in_ab):
		return in_ab*self.ab_norm


class ECCVGenerator(BaseColor):
    def __init__(self, norm_layer=nn.BatchNorm2d):
        super(ECCVGenerator, self).__init__()

        model1=[nn.Conv2d(1, 64, kernel_size=3, stride=1, padding=1, bias=True),]
        model1+=[nn.ReLU(True),]
        model1+=[nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1, bias=True),]
        model1+=[nn.ReLU(True),]
        model1+=[norm_layer(64),]

        model2=[nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1, bias=True),]
        model2+=[nn.ReLU(True),]
        model2+=[nn.Conv2d(128, 128, kernel_size=3, stride=2, padding=1, bias=True),]
        model2+=[nn.ReLU(True),]
        model2+=[norm_layer(128),]

        model3=[nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1, bias=True),]
        model3+=[nn.ReLU(True),]
        model3+=[nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1, bias=True),]
        model3+=[nn.ReLU(True),]
        model3+=[nn.Conv2d(256, 256, kernel_size=3, stride=2, padding=1, bias=True),]
        model3+=[nn.ReLU(True),]
        model3+=[norm_layer(256),]

        model4=[nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1, bias=True),]
        model4+=[nn.ReLU(True),]
        model4+=[nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1, bias=True),]
        model4+=[nn.ReLU(True),]
        model4+=[nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1, bias=True),]
        model4+=[nn.ReLU(True),]
        model4+=[norm_layer(512),]

        model5=[nn.Conv2d(512, 512, kernel_size=3, dilation=2, stride=1, padding=2, bias=True),]
        model5+=[nn.ReLU(True),]
        model5+=[nn.Conv2d(512, 512, kernel_size=3, dilation=2, stride=1, padding=2, bias=True),]
        model5+=[nn.ReLU(True),]
        model5+=[nn.Conv2d(512, 512, kernel_size=3, dilation=2, stride=1, padding=2, bias=True),]
        model5+=[nn.ReLU(True),]
        model5+=[norm_layer(512),]

        model6=[nn.Conv2d(512, 512, kernel_size=3, dilation=2, stride=1, padding=2, bias=True),]
        model6+=[nn.ReLU(True),]
        model6+=[nn.Conv2d(512, 512, kernel_size=3, dilation=2, stride=1, padding=2, bias=True),]
        model6+=[nn.ReLU(True),]
        model6+=[nn.Conv2d(512, 512, kernel_size=3, dilation=2, stride=1, padding=2, bias=True),]
        model6+=[nn.ReLU(True),]
        model6+=[norm_layer(512),]

        model7=[nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1, bias=True),]
        model7+=[nn.ReLU(True),]
        model7+=[nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1, bias=True),]
        model7+=[nn.ReLU(True),]
        model7+=[nn.Conv2d(512, 512, kernel_size=3, stride=1, padding=1, bias=True),]
        model7+=[nn.ReLU(True),]
        model7+=[norm_layer(512),]

        model8=[nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=True),]
        model8+=[nn.ReLU(True),]
        model8+=[nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1, bias=True),]
        model8+=[nn.ReLU(True),]
        model8+=[nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1, bias=True),]
        model8+=[nn.ReLU(True),]

        model8+=[nn.Conv2d(256, 313, kernel_size=1, stride=1, padding=0, bias=True),]

        self.model1 = nn.Sequential(*model1)
        self.model2 = nn.Sequential(*model2)
        self.model3 = nn.Sequential(*model3)
        self.model4 = nn.Sequential(*model4)
        self.model5 = nn.Sequential(*model5)
        self.model6 = nn.Sequential(*model6)
        self.model7 = nn.Sequential(*model7)
        self.model8 = nn.Sequential(*model8)

        self.softmax = nn.Softmax(dim=1)
        self.model_out = nn.Conv2d(313, 2, kernel_size=1, padding=0, dilation=1, stride=1, bias=False)
        self.upsample4 = nn.Upsample(scale_factor=4, mode='bilinear')

    def forward(self, input_l):
        conv1_2 = self.model1(self.normalize_l(input_l))
        conv2_2 = self.model2(conv1_2)
        conv3_3 = self.model3(conv2_2)
        conv4_3 = self.model4(conv3_3)
        conv5_3 = self.model5(conv4_3)
        conv6_3 = self.model6(conv5_3)
        conv7_3 = self.model7(conv6_3)
        conv8_3 = self.model8(conv7_3)
        out_reg = self.model_out(self.softmax(conv8_3))

        return self.unnormalize_ab(self.upsample4(out_reg))

def eccv16(pretrained=True):
	model = ECCVGenerator()
	if(pretrained):
		import torch.utils.model_zoo as model_zoo
		model.load_state_dict(model_zoo.load_url('https://colorizers.s3.us-east-2.amazonaws.com/colorization_release_v2-9b330a0b.pth',map_location='cpu',check_hash=True))
	return model

# %% [markdown]
# ## Util

# %%
def load_img(img_path):
	out_np = np.asarray(Image.open(img_path))
	if(out_np.ndim==2):
		out_np = np.tile(out_np[:,:,None],3)
	return out_np

def resize_img(img, HW=(256,256), resample=3):
	return np.asarray(Image.fromarray(img).resize((HW[1],HW[0]), resample=resample))

def preprocess_img(img_rgb_orig, HW=(256,256), resample=3):
	# return original size L and resized L as torch Tensors
	img_rgb_rs = resize_img(img_rgb_orig, HW=HW, resample=resample)
	
	img_lab_orig = color.rgb2lab(img_rgb_orig)
	img_lab_rs = color.rgb2lab(img_rgb_rs)

	img_l_orig = img_lab_orig[:,:,0]
	img_l_rs = img_lab_rs[:,:,0]

	tens_orig_l = torch.Tensor(img_l_orig)[None,None,:,:]
	tens_rs_l = torch.Tensor(img_l_rs)[None,None,:,:]

	return (tens_orig_l, tens_rs_l)

def postprocess_tens_new(tens_orig_l, out_ab, mode='bilinear'):
	# tens_orig_l 	Batchsize x 1 x H_orig x W_orig
	# out_ab 		Batchsize x 2 x H x W
    Batchsize = tens_orig_l.shape[0]

    output_ = []
    for i in range(Batchsize):
        tens_orig_l_i = tens_orig_l[i][np.newaxis, :, :, :]
        out_ab_i  = out_ab[i][np.newaxis, :, :, :]
        HW_orig_i = tens_orig_l_i.shape[2:]
        HW_i = out_ab_i.shape[2:]

        # call resize function if needed
        if(HW_orig_i[0]!=HW_i[0] or HW_orig_i[1]!=HW_i[1]):
            out_ab_orig_i = F.interpolate(out_ab_i, size=HW_orig_i, mode='bilinear')
        else:
            out_ab_orig_i = out_ab_i

        out_lab_orig_i = torch.cat((tens_orig_l_i, out_ab_orig_i), dim=1)
        #output_.append(color.lab2rgb(out_lab_orig_i.data.cpu().numpy()[0,...].transpose((1,2,0))))
        output_.append(color.lab2rgb(out_lab_orig_i.data.cpu().numpy()[0,...].transpose((1,2,0))).transpose((2,0,1)))
    return np.array(output_)

# %% [markdown]
# # Image Dataset

# %%
batch_size = 4
n_cpu = 0
out_channels = 3

class ImageDataset(Dataset):
    def __init__(self, root, transform): #, shape):
        #height, width = shape
        self.transform = transform

        self.files = sorted(glob.glob(root + "/*.*"))

    def __getitem__(self, index):
        
        black_path = self.files[index % len(self.files)]
        color_path = black_path.replace('black','color')
        
        img_black = np.asarray(Image.open(black_path))
        if(img_black.ndim==2):
            img_black = np.tile(img_black[:,:,None],3)
        (tens_l_orig, tens_l_rs) = preprocess_img(img_black, HW=(400, 400))
        #img_bw = postprocess_tens(tens_l_orig, torch.cat((0*tens_l_orig,0*tens_l_orig),dim=1))
        #img_black = self.transform(img_black)
        
        
        img_color = Image.open(color_path)
        img_color = self.transform(img_color)

        return {"black": tens_l_rs.squeeze(0), 'orig': tens_l_orig.squeeze(0), "color": img_color}


    def __len__(self):
        return len(self.files)

root = '../input/image-colorization-dataset/data/train_black/'
transform = transforms.Compose(
            [
                #transforms.Resize((shape[0], shape[1]), Image.BICUBIC),
                transforms.ToTensor(),
                #transforms.Normalize(mean, std),
            ]
        )
dataloader = DataLoader(
    ImageDataset(root, transform),
    batch_size=batch_size,
    shuffle=True,
    num_workers=n_cpu,
)

# %%
dataiter = iter(dataloader)
data = dataiter.next()

i = 1
img = data['black'][i].permute(1, 2, 0)
print(img.shape)
t = np.zeros((400, 400, 3))
t[..., 0] = img[..., 0]
t = color.lab2rgb(t)
plt.imshow(t)
plt.show()

img = data['orig'][i].permute(1, 2, 0)
print(img.shape)
t = np.zeros((400, 400, 3))
t[..., 0] = img[..., 0]
t = color.lab2rgb(t)
plt.imshow(t)
plt.show()

print(img.shape)
img = data['color'][i].permute(1, 2, 0)
plt.imshow(img)
plt.show()
# Out:
# torch.Size([400, 400, 1])
# torch.Size([400, 400, 1])
# torch.Size([400, 400, 1])

# %% [markdown]
# # Initialising Models and Training Params

# %%
class color_ecv(nn.Module):
    def __init__(self, in_channels):
        super(color_ecv, self).__init__()
        
        self.model = eccv16(pretrained=True)
    
    def forward(self, x):
        ecv_output = self.model(x)
        return ecv_output

# %%
os.makedirs("colorit_gan/images", exist_ok=True)
os.makedirs("colorit_gan/saved_models", exist_ok=True)

# %%
start_epoch = 0
n_epochs= 50

lr = 0.0002
b1 = 0.5
b2 = 0.999
decay_epoch = 100
in_channels = 1
out_channels = 3
sample_interval = 100
checkpoint_interval = 1

cuda = torch.cuda.is_available()

# %%
shape = (400, 400)

# Initialize generator and discriminator
generator = color_ecv(in_channels = 3)
discriminator = Discriminator(input_shape=(out_channels, *shape))
feature_extractor = FeatureExtractor()

# Set feature extractor to inference mode
feature_extractor.eval()

# Losses
criterion_GAN = torch.nn.MSELoss()
criterion_content = torch.nn.L1Loss()

if cuda:
    generator = generator.cuda()
    discriminator = discriminator.cuda()
    feature_extractor = feature_extractor.cuda()
    criterion_GAN = criterion_GAN.cuda()
    criterion_content = criterion_content.cuda()
# Out:
# Downloading: "https://colorizers.s3.us-east-2.amazonaws.com/colorization_release_v2-9b330a0b.pth" to /root/.cache/torch/hub/checkpoints/colorization_release_v2-9b330a0b.pth
#   0%|          | 0.00/123M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
if start_epoch != 0:
    # Load pretrained models
    generator.load_state_dict(torch.load("colorit_gan/saved_models/generator_"+str(start_epoch-1)+".pth"))
    discriminator.load_state_dict(torch.load("colorit_gan/saved_models/discriminator_"+str(start_epoch-1)+".pth"))

# %%
# Optimizers
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))

Tensor = torch.cuda.FloatTensor if cuda else torch.Tensor

# %% [markdown]
# # Training

# %%
# ----------
#  Training
# ----------

for epoch in range(start_epoch, n_epochs):
    for i, imgs in enumerate(dataloader):

        # imgs_black : Light Channel of the Image in Model Shape
        # imgs_black_orig : Light Channel of the Image in Original Image Shape
        # imgs_color : Colourfull Image Provided 
        # gen_ab : A and B channel generated by the generator
        # gen_color : Colourfull Image generated by the Generator after postprocessing
        
        
        # Configure model input
        imgs_black = Variable(imgs["black"].type(Tensor))
        imgs_black_orig = Variable(imgs["orig"].type(Tensor))
        imgs_color = Variable(imgs["color"].type(Tensor))

        # Adversarial ground truths
        valid = Variable(Tensor(np.ones((imgs_black.size(0), *discriminator.output_shape))), requires_grad=False)
        fake = Variable(Tensor(np.zeros((imgs_black.size(0), *discriminator.output_shape))), requires_grad=False)

        # ------------------
        #  Train Generators
        # ------------------

        optimizer_G.zero_grad()

        # Generate a high resolution image from low resolution input
        gen_ab = generator(imgs_black)
        gen_color = postprocess_tens_new(imgs_black_orig, gen_ab)
        if cuda:
            gen_color = torch.from_numpy(gen_color).to('cuda')

        # Adversarial loss
        loss_GAN = criterion_GAN(discriminator(gen_color), valid)

        # Content loss
        gen_features = feature_extractor(gen_color.detach())
        real_features = feature_extractor(imgs_color.detach())
        loss_content = criterion_content(gen_features, real_features.detach())

        # Total loss
        loss_G = loss_content + 1e-3 * loss_GAN

        loss_G.backward()
        optimizer_G.step()

        # ---------------------
        #  Train Discriminator
        # ---------------------

        optimizer_D.zero_grad()

        # Loss of real and fake images
        loss_real = criterion_GAN(discriminator(imgs_color), valid)
        loss_fake = criterion_GAN(discriminator(gen_color.detach()), fake)

        # Total loss
        loss_D = (loss_real + loss_fake) / 2

        loss_D.backward()
        optimizer_D.step()

        # --------------
        #  Log Progress
        # --------------

        sys.stdout.write(
            "[Epoch %d/%d] [Batch %d/%d] [D loss: %f] [G loss: %f]"
            % (epoch, n_epochs, i, len(dataloader), loss_D.item(), loss_G.item())
        )

        batches_done = epoch * len(dataloader) + i
        if batches_done % sample_interval == 0:
            # Save image grid with upsampled inputs and SRGAN outputs
            #imgs_lr = nn.functional.interpolate(imgs_lr, scale_factor=4)
            gen_color = make_grid(gen_color.detach(), nrow=1, normalize=True)
            imgs_black_orig = make_grid(imgs_black_orig, nrow=1, normalize=True)
            img_grid = torch.cat((imgs_black_orig, gen_color), -1)
            save_image(img_grid, "./colorit_gan/images/%d.png" % batches_done, normalize=False)

    if checkpoint_interval != -1 and epoch % checkpoint_interval == 0:
        # Save model checkpoints
        torch.save(generator.state_dict(), "./colorit_gan/saved_models/generator_%d.pth" % epoch)
        torch.save(discriminator.state_dict(), "./colorit_gan/saved_models/discriminator_%d.pth" % epoch)
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# [Epoch 0/50] [Batch 0/1250] [D loss: 0.877288] [G loss: 0.231747]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 14 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 3 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 20 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 1 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 1/1250] [D loss: 1.580160] [G loss: 0.242827]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 49 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 2/1250] [D loss: 1.908455] [G loss: 0.242125]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 5 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 3/1250] [D loss: 2.646693] [G loss: 0.238818]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 65 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 4/1250] [D loss: 1.306828] [G loss: 0.220234][Epoch 0/50] [Batch 5/1250] [D loss: 0.450207] [G loss: 0.182696]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 42 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 44 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 6/1250] [D loss: 0.371504] [G loss: 0.224159]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 168 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 7/1250] [D loss: 0.322304] [G loss: 0.255679]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 80 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 4 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 8/1250] [D loss: 0.296056] [G loss: 0.194275][Epoch 0/50] [Batch 9/1250] [D loss: 0.293162] [G loss: 0.159643]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 7 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 10/1250] [D loss: 0.292122] [G loss: 0.220599]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 15 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 40 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 11/1250] [D loss: 0.270100] [G loss: 0.239919][Epoch 0/50] [Batch 12/1250] [D loss: 0.297494] [G loss: 0.184556]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 2 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 121 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 13/1250] [D loss: 0.269300] [G loss: 0.261301]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 12 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 14/1250] [D loss: 0.278656] [G loss: 0.211518]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 48 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 15/1250] [D loss: 0.277628] [G loss: 0.232347]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 30 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 16/1250] [D loss: 0.357219] [G loss: 0.217970][Epoch 0/50] [Batch 17/1250] [D loss: 0.347238] [G loss: 0.226949]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 140 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 18/1250] [D loss: 0.292220] [G loss: 0.164623][Epoch 0/50] [Batch 19/1250] [D loss: 0.263238] [G loss: 0.182975][Epoch 0/50] [Batch 20/1250] [D loss: 0.284927] [G loss: 0.215919][Epoch 0/50] [Batch 21/1250] [D loss: 0.268121] [G loss: 0.187993]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 9 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 22/1250] [D loss: 0.254761] [G loss: 0.218768]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 10 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 23/1250] [D loss: 0.307771] [G loss: 0.231747]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 22 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 24/1250] [D loss: 0.319575] [G loss: 0.198983]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 6 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 34 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 25/1250] [D loss: 0.262009] [G loss: 0.199522]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 13 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 26/1250] [D loss: 0.232651] [G loss: 0.187699][Epoch 0/50] [Batch 27/1250] [D loss: 0.266484] [G loss: 0.206119][Epoch 0/50] [Batch 28/1250] [D loss: 0.240638] [G loss: 0.291210][Epoch 0/50] [Batch 29/1250] [D loss: 0.263835] [G loss: 0.265071][Epoch 0/50] [Batch 30/1250] [D loss: 0.248780] [G loss: 0.171926]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 21 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 26 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 266 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 31/1250] [D loss: 0.248947] [G loss: 0.240718][Epoch 0/50] [Batch 32/1250] [D loss: 0.299059] [G loss: 0.203711][Epoch 0/50] [Batch 33/1250] [D loss: 0.266350] [G loss: 0.183897][Epoch 0/50] [Batch 34/1250] [D loss: 0.237999] [G loss: 0.180562]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 95 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 35/1250] [D loss: 0.224646] [G loss: 0.219494]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 29 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 36/1250] [D loss: 0.215009] [G loss: 0.160942]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 61 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 37/1250] [D loss: 0.257588] [G loss: 0.268889][Epoch 0/50] [Batch 38/1250] [D loss: 0.239630] [G loss: 0.192069][Epoch 0/50] [Batch 39/1250] [D loss: 0.240794] [G loss: 0.180244][Epoch 0/50] [Batch 40/1250] [D loss: 0.332505] [G loss: 0.222789]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 24 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 11 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 41/1250] [D loss: 0.305430] [G loss: 0.211591][Epoch 0/50] [Batch 42/1250] [D loss: 0.263294] [G loss: 0.211285][Epoch 0/50] [Batch 43/1250] [D loss: 0.250422] [G loss: 0.179724][Epoch 0/50] [Batch 44/1250] [D loss: 0.257968] [G loss: 0.230574]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 103 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 45/1250] [D loss: 0.262340] [G loss: 0.217891]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 8 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 46/1250] [D loss: 0.262354] [G loss: 0.166234]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 71 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 78 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 47/1250] [D loss: 0.230103] [G loss: 0.253276][Epoch 0/50] [Batch 48/1250] [D loss: 0.273123] [G loss: 0.221324][Epoch 0/50] [Batch 49/1250] [D loss: 0.231354] [G loss: 0.253898][Epoch 0/50] [Batch 50/1250] [D loss: 0.255198] [G loss: 0.214882][Epoch 0/50] [Batch 51/1250] [D loss: 0.297311] [G loss: 0.242847][Epoch 0/50] [Batch 52/1250] [D loss: 0.256628] [G loss: 0.188257][Epoch 0/50] [Batch 53/1250] [D loss: 0.237160] [G loss: 0.227003]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 37 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 54/1250] [D loss: 0.191898] [G loss: 0.133951]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 430 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 55/1250] [D loss: 0.216846] [G loss: 0.220368][Epoch 0/50] [Batch 56/1250] [D loss: 0.197056] [G loss: 0.209276]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 122 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 57/1250] [D loss: 0.279667] [G loss: 0.232870][Epoch 0/50] [Batch 58/1250] [D loss: 0.236757] [G loss: 0.190810][Epoch 0/50] [Batch 59/1250] [D loss: 0.199270] [G loss: 0.202725][Epoch 0/50] [Batch 60/1250] [D loss: 0.229473] [G loss: 0.189826][Epoch 0/50] [Batch 61/1250] [D loss: 0.237390] [G loss: 0.202160][Epoch 0/50] [Batch 62/1250] [D loss: 0.240314] [G loss: 0.205009][Epoch 0/50] [Batch 63/1250] [D loss: 0.229839] [G loss: 0.177922][Epoch 0/50] [Batch 64/1250] [D loss: 0.195137] [G loss: 0.162897]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 38 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 65/1250] [D loss: 0.198838] [G loss: 0.208362][Epoch 0/50] [Batch 66/1250] [D loss: 0.193840] [G loss: 0.191922][Epoch 0/50] [Batch 67/1250] [D loss: 0.181378] [G loss: 0.165517]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 153 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 68/1250] [D loss: 0.224251] [G loss: 0.185618][Epoch 0/50] [Batch 69/1250] [D loss: 0.228918] [G loss: 0.294143]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 47 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 70 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 70/1250] [D loss: 0.191220] [G loss: 0.223866]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 35 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 71/1250] [D loss: 0.201002] [G loss: 0.218971][Epoch 0/50] [Batch 72/1250] [D loss: 0.208712] [G loss: 0.180413]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 33 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 73/1250] [D loss: 0.227657] [G loss: 0.216020][Epoch 0/50] [Batch 74/1250] [D loss: 0.292127] [G loss: 0.221689][Epoch 0/50] [Batch 75/1250] [D loss: 0.193960] [G loss: 0.186470][Epoch 0/50] [Batch 76/1250] [D loss: 0.222481] [G loss: 0.179833]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 23 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 77/1250] [D loss: 0.193118] [G loss: 0.217247][Epoch 0/50] [Batch 78/1250] [D loss: 0.267271] [G loss: 0.225975]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 131 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 79/1250] [D loss: 0.191726] [G loss: 0.223169][Epoch 0/50] [Batch 80/1250] [D loss: 0.254559] [G loss: 0.178766][Epoch 0/50] [Batch 81/1250] [D loss: 0.209183] [G loss: 0.245615][Epoch 0/50] [Batch 82/1250] [D loss: 0.244722] [G loss: 0.229994][Epoch 0/50] [Batch 83/1250] [D loss: 0.249289] [G loss: 0.188565][Epoch 0/50] [Batch 84/1250] [D loss: 0.311854] [G loss: 0.234585][Epoch 0/50] [Batch 85/1250] [D loss: 0.332054] [G loss: 0.153404][Epoch 0/50] [Batch 86/1250] [D loss: 0.278889] [G loss: 0.192631][Epoch 0/50] [Batch 87/1250] [D loss: 0.206052] [G loss: 0.202011]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 19 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 18 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 88/1250] [D loss: 0.169961] [G loss: 0.217355][Epoch 0/50] [Batch 89/1250] [D loss: 0.175697] [G loss: 0.190951][Epoch 0/50] [Batch 90/1250] [D loss: 0.242888] [G loss: 0.165225][Epoch 0/50] [Batch 91/1250] [D loss: 0.190606] [G loss: 0.250790][Epoch 0/50] [Batch 92/1250] [D loss: 0.203775] [G loss: 0.204090][Epoch 0/50] [Batch 93/1250] [D loss: 0.174311] [G loss: 0.243571][Epoch 0/50] [Batch 94/1250] [D loss: 0.200437] [G loss: 0.191546]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 28 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 95/1250] [D loss: 0.342123] [G loss: 0.255941]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 52 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 96/1250] [D loss: 0.223289] [G loss: 0.215142][Epoch 0/50] [Batch 97/1250] [D loss: 0.268643] [G loss: 0.153812]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 41 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 123 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 98/1250] [D loss: 0.337704] [G loss: 0.180541]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 54 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 99/1250] [D loss: 0.384744] [G loss: 0.165647][Epoch 0/50] [Batch 100/1250] [D loss: 0.245027] [G loss: 0.151066]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 238 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 101/1250] [D loss: 0.244850] [G loss: 0.217473][Epoch 0/50] [Batch 102/1250] [D loss: 0.209404] [G loss: 0.175954]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 393 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 103/1250] [D loss: 0.161700] [G loss: 0.169899][Epoch 0/50] [Batch 104/1250] [D loss: 0.175443] [G loss: 0.183056][Epoch 0/50] [Batch 105/1250] [D loss: 0.147237] [G loss: 0.201459]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 45 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 106/1250] [D loss: 0.154905] [G loss: 0.239205][Epoch 0/50] [Batch 107/1250] [D loss: 0.265106] [G loss: 0.205408][Epoch 0/50] [Batch 108/1250] [D loss: 0.251377] [G loss: 0.236051][Epoch 0/50] [Batch 109/1250] [D loss: 0.295742] [G loss: 0.166726][Epoch 0/50] [Batch 110/1250] [D loss: 0.242989] [G loss: 0.182376]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 116 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 39 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 111/1250] [D loss: 0.284943] [G loss: 0.199701][Epoch 0/50] [Batch 112/1250] [D loss: 0.330768] [G loss: 0.272446][Epoch 0/50] [Batch 113/1250] [D loss: 0.235467] [G loss: 0.257588][Epoch 0/50] [Batch 114/1250] [D loss: 0.224331] [G loss: 0.166743][Epoch 0/50] [Batch 115/1250] [D loss: 0.174389] [G loss: 0.225333][Epoch 0/50] [Batch 116/1250] [D loss: 0.220950] [G loss: 0.188052][Epoch 0/50] [Batch 117/1250] [D loss: 0.270936] [G loss: 0.178525]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 89 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 118/1250] [D loss: 0.191499] [G loss: 0.182992]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 105 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 119/1250] [D loss: 0.206495] [G loss: 0.233096]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 32 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 120/1250] [D loss: 0.120518] [G loss: 0.211954][Epoch 0/50] [Batch 121/1250] [D loss: 0.176708] [G loss: 0.167322][Epoch 0/50] [Batch 122/1250] [D loss: 0.118004] [G loss: 0.219533][Epoch 0/50] [Batch 123/1250] [D loss: 0.123412] [G loss: 0.194158][Epoch 0/50] [Batch 124/1250] [D loss: 0.179549] [G loss: 0.241078][Epoch 0/50] [Batch 125/1250] [D loss: 0.163278] [G loss: 0.165807][Epoch 0/50] [Batch 126/1250] [D loss: 0.148047] [G loss: 0.179271][Epoch 0/50] [Batch 127/1250] [D loss: 0.136222] [G loss: 0.163529][Epoch 0/50] [Batch 128/1250] [D loss: 0.243179] [G loss: 0.286526][Epoch 0/50] [Batch 129/1250] [D loss: 0.222315] [G loss: 0.141524][Epoch 0/50] [Batch 130/1250] [D loss: 0.389326] [G loss: 0.232895]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 74 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 131/1250] [D loss: 0.314749] [G loss: 0.187784][Epoch 0/50] [Batch 132/1250] [D loss: 0.150888] [G loss: 0.198909][Epoch 0/50] [Batch 133/1250] [D loss: 0.271341] [G loss: 0.270013][Epoch 0/50] [Batch 134/1250] [D loss: 0.168756] [G loss: 0.176747][Epoch 0/50] [Batch 135/1250] [D loss: 0.168274] [G loss: 0.209019][Epoch 0/50] [Batch 136/1250] [D loss: 0.192189] [G loss: 0.156931][Epoch 0/50] [Batch 137/1250] [D loss: 0.133769] [G loss: 0.182920]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 302 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 138/1250] [D loss: 0.371563] [G loss: 0.228275][Epoch 0/50] [Batch 139/1250] [D loss: 0.140310] [G loss: 0.197655][Epoch 0/50] [Batch 140/1250] [D loss: 0.183352] [G loss: 0.168911][Epoch 0/50] [Batch 141/1250] [D loss: 0.080298] [G loss: 0.168219]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 111 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 142/1250] [D loss: 0.201679] [G loss: 0.165901][Epoch 0/50] [Batch 143/1250] [D loss: 0.220304] [G loss: 0.285663][Epoch 0/50] [Batch 144/1250] [D loss: 0.116139] [G loss: 0.251155]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 17 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 145/1250] [D loss: 0.190379] [G loss: 0.220838][Epoch 0/50] [Batch 146/1250] [D loss: 0.111152] [G loss: 0.194273][Epoch 0/50] [Batch 147/1250] [D loss: 0.123868] [G loss: 0.177099][Epoch 0/50] [Batch 148/1250] [D loss: 0.134113] [G loss: 0.186251]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 180 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 149/1250] [D loss: 0.216276] [G loss: 0.181669][Epoch 0/50] [Batch 150/1250] [D loss: 0.159005] [G loss: 0.221733][Epoch 0/50] [Batch 151/1250] [D loss: 0.125171] [G loss: 0.190785][Epoch 0/50] [Batch 152/1250] [D loss: 0.247262] [G loss: 0.271843][Epoch 0/50] [Batch 153/1250] [D loss: 0.157457] [G loss: 0.211108]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 189 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 765 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 154/1250] [D loss: 0.592523] [G loss: 0.253197][Epoch 0/50] [Batch 155/1250] [D loss: 0.341758] [G loss: 0.239233]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 81 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 156/1250] [D loss: 0.235856] [G loss: 0.204269][Epoch 0/50] [Batch 157/1250] [D loss: 0.267472] [G loss: 0.207254]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 88 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 158/1250] [D loss: 0.267003] [G loss: 0.228016]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 16 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 159/1250] [D loss: 0.232099] [G loss: 0.261578]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 166 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 160/1250] [D loss: 0.250654] [G loss: 0.279125][Epoch 0/50] [Batch 161/1250] [D loss: 0.180046] [G loss: 0.201208]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 55 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 162/1250] [D loss: 0.154367] [G loss: 0.227682]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 94 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 163/1250] [D loss: 0.315182] [G loss: 0.219836][Epoch 0/50] [Batch 164/1250] [D loss: 0.271660] [G loss: 0.186300][Epoch 0/50] [Batch 165/1250] [D loss: 0.142706] [G loss: 0.163536][Epoch 0/50] [Batch 166/1250] [D loss: 0.169626] [G loss: 0.215308][Epoch 0/50] [Batch 167/1250] [D loss: 0.186905] [G loss: 0.244298]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 92 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 168/1250] [D loss: 0.208117] [G loss: 0.262703][Epoch 0/50] [Batch 169/1250] [D loss: 0.145313] [G loss: 0.201797][Epoch 0/50] [Batch 170/1250] [D loss: 0.188663] [G loss: 0.212338][Epoch 0/50] [Batch 171/1250] [D loss: 0.151213] [G loss: 0.285295][Epoch 0/50] [Batch 172/1250] [D loss: 0.162106] [G loss: 0.167733]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 66 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 173/1250] [D loss: 0.185540] [G loss: 0.202383][Epoch 0/50] [Batch 174/1250] [D loss: 0.265187] [G loss: 0.195275][Epoch 0/50] [Batch 175/1250] [D loss: 0.192480] [G loss: 0.200085][Epoch 0/50] [Batch 176/1250] [D loss: 0.257277] [G loss: 0.235816][Epoch 0/50] [Batch 177/1250] [D loss: 0.238593] [G loss: 0.239718][Epoch 0/50] [Batch 178/1250] [D loss: 0.296826] [G loss: 0.247178]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 525 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 179/1250] [D loss: 0.220579] [G loss: 0.189252]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 73 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 180/1250] [D loss: 0.255610] [G loss: 0.257439][Epoch 0/50] [Batch 181/1250] [D loss: 0.174838] [G loss: 0.184059][Epoch 0/50] [Batch 182/1250] [D loss: 0.194711] [G loss: 0.243198][Epoch 0/50] [Batch 183/1250] [D loss: 0.145024] [G loss: 0.238463][Epoch 0/50] [Batch 184/1250] [D loss: 0.353823] [G loss: 0.194241][Epoch 0/50] [Batch 185/1250] [D loss: 0.322657] [G loss: 0.210194][Epoch 0/50] [Batch 186/1250] [D loss: 0.238769] [G loss: 0.263505][Epoch 0/50] [Batch 187/1250] [D loss: 0.198055] [G loss: 0.226082][Epoch 0/50] [Batch 188/1250] [D loss: 0.156840] [G loss: 0.307818][Epoch 0/50] [Batch 189/1250] [D loss: 0.147147] [G loss: 0.284291][Epoch 0/50] [Batch 190/1250] [D loss: 0.211832] [G loss: 0.213509][Epoch 0/50] [Batch 191/1250] [D loss: 0.212761] [G loss: 0.149282][Epoch 0/50] [Batch 192/1250] [D loss: 0.163945] [G loss: 0.250472][Epoch 0/50] [Batch 193/1250] [D loss: 0.178863] [G loss: 0.188641]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 53 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 194/1250] [D loss: 0.080827] [G loss: 0.130969][Epoch 0/50] [Batch 195/1250] [D loss: 0.120318] [G loss: 0.266153][Epoch 0/50] [Batch 196/1250] [D loss: 0.233712] [G loss: 0.182050][Epoch 0/50] [Batch 197/1250] [D loss: 0.351152] [G loss: 0.229063]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 149 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 198/1250] [D loss: 0.167821] [G loss: 0.256656][Epoch 0/50] [Batch 199/1250] [D loss: 0.260131] [G loss: 0.193568][Epoch 0/50] [Batch 200/1250] [D loss: 0.336985] [G loss: 0.169034][Epoch 0/50] [Batch 201/1250] [D loss: 0.158633] [G loss: 0.200674][Epoch 0/50] [Batch 202/1250] [D loss: 0.180477] [G loss: 0.238626][Epoch 0/50] [Batch 203/1250] [D loss: 0.109276] [G loss: 0.213989][Epoch 0/50] [Batch 204/1250] [D loss: 0.110049] [G loss: 0.166824]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 139 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 386 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 205/1250] [D loss: 0.170762] [G loss: 0.256008][Epoch 0/50] [Batch 206/1250] [D loss: 0.140504] [G loss: 0.194994][Epoch 0/50] [Batch 207/1250] [D loss: 0.137781] [G loss: 0.207254][Epoch 0/50] [Batch 208/1250] [D loss: 0.167248] [G loss: 0.229681][Epoch 0/50] [Batch 209/1250] [D loss: 0.109686] [G loss: 0.197565][Epoch 0/50] [Batch 210/1250] [D loss: 0.128257] [G loss: 0.209517][Epoch 0/50] [Batch 211/1250] [D loss: 0.199712] [G loss: 0.233813][Epoch 0/50] [Batch 212/1250] [D loss: 0.207294] [G loss: 0.193230][Epoch 0/50] [Batch 213/1250] [D loss: 0.117017] [G loss: 0.238236]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 57 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 214/1250] [D loss: 0.060008] [G loss: 0.236592][Epoch 0/50] [Batch 215/1250] [D loss: 0.183626] [G loss: 0.189786][Epoch 0/50] [Batch 216/1250] [D loss: 0.131175] [G loss: 0.192730][Epoch 0/50] [Batch 217/1250] [D loss: 0.105747] [G loss: 0.207578][Epoch 0/50] [Batch 218/1250] [D loss: 0.172640] [G loss: 0.217606][Epoch 0/50] [Batch 219/1250] [D loss: 0.131519] [G loss: 0.205760][Epoch 0/50] [Batch 220/1250] [D loss: 0.164571] [G loss: 0.169787]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 330 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 221/1250] [D loss: 0.076241] [G loss: 0.247458][Epoch 0/50] [Batch 222/1250] [D loss: 0.064581] [G loss: 0.257696][Epoch 0/50] [Batch 223/1250] [D loss: 0.022886] [G loss: 0.183532]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 50 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 224/1250] [D loss: 0.099692] [G loss: 0.243559]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 77 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 225/1250] [D loss: 0.549768] [G loss: 0.317646][Epoch 0/50] [Batch 226/1250] [D loss: 0.196299] [G loss: 0.213217]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 56 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 25 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 227/1250] [D loss: 0.246071] [G loss: 0.220657][Epoch 0/50] [Batch 228/1250] [D loss: 0.221109] [G loss: 0.190963][Epoch 0/50] [Batch 229/1250] [D loss: 0.125762] [G loss: 0.227843][Epoch 0/50] [Batch 230/1250] [D loss: 0.135784] [G loss: 0.223658][Epoch 0/50] [Batch 231/1250] [D loss: 0.118062] [G loss: 0.218010][Epoch 0/50] [Batch 232/1250] [D loss: 0.104780] [G loss: 0.210456][Epoch 0/50] [Batch 233/1250] [D loss: 0.090647] [G loss: 0.190051][Epoch 0/50] [Batch 234/1250] [D loss: 0.117588] [G loss: 0.247393][Epoch 0/50] [Batch 235/1250] [D loss: 0.142413] [G loss: 0.181885][Epoch 0/50] [Batch 236/1250] [D loss: 0.228665] [G loss: 0.153363][Epoch 0/50] [Batch 237/1250] [D loss: 0.240288] [G loss: 0.198683][Epoch 0/50] [Batch 238/1250] [D loss: 0.030915] [G loss: 0.163401]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 435 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 239/1250] [D loss: 0.095098] [G loss: 0.263289][Epoch 0/50] [Batch 240/1250] [D loss: 0.084085] [G loss: 0.213373][Epoch 0/50] [Batch 241/1250] [D loss: 0.071869] [G loss: 0.189060][Epoch 0/50] [Batch 242/1250] [D loss: 0.043384] [G loss: 0.193204]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 31 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 475 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 243/1250] [D loss: 0.268566] [G loss: 0.191516][Epoch 0/50] [Batch 244/1250] [D loss: 0.261371] [G loss: 0.229403][Epoch 0/50] [Batch 245/1250] [D loss: 0.062521] [G loss: 0.184652][Epoch 0/50] [Batch 246/1250] [D loss: 0.199678] [G loss: 0.258446][Epoch 0/50] [Batch 247/1250] [D loss: 0.095398] [G loss: 0.160402][Epoch 0/50] [Batch 248/1250] [D loss: 0.227905] [G loss: 0.290929][Epoch 0/50] [Batch 249/1250] [D loss: 0.297416] [G loss: 0.182980][Epoch 0/50] [Batch 250/1250] [D loss: 0.117406] [G loss: 0.209649][Epoch 0/50] [Batch 251/1250] [D loss: 0.181252] [G loss: 0.235776][Epoch 0/50] [Batch 252/1250] [D loss: 0.139753] [G loss: 0.182607][Epoch 0/50] [Batch 253/1250] [D loss: 0.536244] [G loss: 0.187862][Epoch 0/50] [Batch 254/1250] [D loss: 0.178388] [G loss: 0.256131]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 125 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 255/1250] [D loss: 0.191240] [G loss: 0.156293][Epoch 0/50] [Batch 256/1250] [D loss: 0.178603] [G loss: 0.265794][Epoch 0/50] [Batch 257/1250] [D loss: 0.204299] [G loss: 0.133709][Epoch 0/50] [Batch 258/1250] [D loss: 0.121065] [G loss: 0.210348][Epoch 0/50] [Batch 259/1250] [D loss: 0.174421] [G loss: 0.196862][Epoch 0/50] [Batch 260/1250] [D loss: 0.223076] [G loss: 0.151441][Epoch 0/50] [Batch 261/1250] [D loss: 0.062687] [G loss: 0.215918][Epoch 0/50] [Batch 262/1250] [D loss: 0.346664] [G loss: 0.203075][Epoch 0/50] [Batch 263/1250] [D loss: 0.117883] [G loss: 0.257688][Epoch 0/50] [Batch 264/1250] [D loss: 0.092563] [G loss: 0.197728][Epoch 0/50] [Batch 265/1250] [D loss: 0.338823] [G loss: 0.247870][Epoch 0/50] [Batch 266/1250] [D loss: 0.183938] [G loss: 0.200122][Epoch 0/50] [Batch 267/1250] [D loss: 0.239553] [G loss: 0.199660][Epoch 0/50] [Batch 268/1250] [D loss: 0.065510] [G loss: 0.191315][Epoch 0/50] [Batch 269/1250] [D loss: 0.141169] [G loss: 0.177673][Epoch 0/50] [Batch 270/1250] [D loss: 0.068167] [G loss: 0.224680][Epoch 0/50] [Batch 271/1250] [D loss: 0.035172] [G loss: 0.178934][Epoch 0/50] [Batch 272/1250] [D loss: 0.083174] [G loss: 0.187241]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 36 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 273/1250] [D loss: 0.079235] [G loss: 0.256198][Epoch 0/50] [Batch 274/1250] [D loss: 0.028601] [G loss: 0.241112][Epoch 0/50] [Batch 275/1250] [D loss: 0.215648] [G loss: 0.164400][Epoch 0/50] [Batch 276/1250] [D loss: 0.330977] [G loss: 0.203962]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 27 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 277/1250] [D loss: 0.143420] [G loss: 0.221644][Epoch 0/50] [Batch 278/1250] [D loss: 0.138534] [G loss: 0.238113][Epoch 0/50] [Batch 279/1250] [D loss: 0.161653] [G loss: 0.238039][Epoch 0/50] [Batch 280/1250] [D loss: 0.245036] [G loss: 0.194887][Epoch 0/50] [Batch 281/1250] [D loss: 0.118320] [G loss: 0.205720][Epoch 0/50] [Batch 282/1250] [D loss: 0.096498] [G loss: 0.176850][Epoch 0/50] [Batch 283/1250] [D loss: 0.138686] [G loss: 0.175523][Epoch 0/50] [Batch 284/1250] [D loss: 0.473790] [G loss: 0.251525][Epoch 0/50] [Batch 285/1250] [D loss: 0.207970] [G loss: 0.175222][Epoch 0/50] [Batch 286/1250] [D loss: 0.125677] [G loss: 0.231999][Epoch 0/50] [Batch 287/1250] [D loss: 0.141496] [G loss: 0.250714]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 258 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 288/1250] [D loss: 0.093126] [G loss: 0.278493][Epoch 0/50] [Batch 289/1250] [D loss: 0.313901] [G loss: 0.272258][Epoch 0/50] [Batch 290/1250] [D loss: 0.089837] [G loss: 0.184601]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 126 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 291/1250] [D loss: 0.051511] [G loss: 0.207438][Epoch 0/50] [Batch 292/1250] [D loss: 0.255552] [G loss: 0.240566][Epoch 0/50] [Batch 293/1250] [D loss: 0.051970] [G loss: 0.163901][Epoch 0/50] [Batch 294/1250] [D loss: 0.141046] [G loss: 0.140422][Epoch 0/50] [Batch 295/1250] [D loss: 0.056264] [G loss: 0.172424][Epoch 0/50] [Batch 296/1250] [D loss: 0.119381] [G loss: 0.185187][Epoch 0/50] [Batch 297/1250] [D loss: 0.080022] [G loss: 0.196762][Epoch 0/50] [Batch 298/1250] [D loss: 0.105655] [G loss: 0.227023][Epoch 0/50] [Batch 299/1250] [D loss: 0.060076] [G loss: 0.206201][Epoch 0/50] [Batch 300/1250] [D loss: 0.010392] [G loss: 0.206870][Epoch 0/50] [Batch 301/1250] [D loss: 0.053644] [G loss: 0.176955]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 479 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 302/1250] [D loss: 0.421175] [G loss: 0.258734][Epoch 0/50] [Batch 303/1250] [D loss: 0.354306] [G loss: 0.183674][Epoch 0/50] [Batch 304/1250] [D loss: 0.114426] [G loss: 0.234407]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 179 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 305/1250] [D loss: 0.123491] [G loss: 0.268804][Epoch 0/50] [Batch 306/1250] [D loss: 0.131677] [G loss: 0.214770][Epoch 0/50] [Batch 307/1250] [D loss: 0.171631] [G loss: 0.178944][Epoch 0/50] [Batch 308/1250] [D loss: 0.099477] [G loss: 0.226042][Epoch 0/50] [Batch 309/1250] [D loss: 0.044411] [G loss: 0.192704][Epoch 0/50] [Batch 310/1250] [D loss: 0.040416] [G loss: 0.153823][Epoch 0/50] [Batch 311/1250] [D loss: 0.122274] [G loss: 0.197370][Epoch 0/50] [Batch 312/1250] [D loss: 0.077464] [G loss: 0.190226][Epoch 0/50] [Batch 313/1250] [D loss: 0.123770] [G loss: 0.179575][Epoch 0/50] [Batch 314/1250] [D loss: 0.182137] [G loss: 0.207429][Epoch 0/50] [Batch 315/1250] [D loss: 0.174711] [G loss: 0.177780]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 82 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 316/1250] [D loss: 0.160957] [G loss: 0.171735][Epoch 0/50] [Batch 317/1250] [D loss: 0.088991] [G loss: 0.167084][Epoch 0/50] [Batch 318/1250] [D loss: 0.196344] [G loss: 0.231451][Epoch 0/50] [Batch 319/1250] [D loss: 0.256825] [G loss: 0.195980][Epoch 0/50] [Batch 320/1250] [D loss: 0.219303] [G loss: 0.174791][Epoch 0/50] [Batch 321/1250] [D loss: 0.332619] [G loss: 0.285741][Epoch 0/50] [Batch 322/1250] [D loss: 0.308282] [G loss: 0.231158]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 79 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 323/1250] [D loss: 0.139854] [G loss: 0.253043][Epoch 0/50] [Batch 324/1250] [D loss: 0.133791] [G loss: 0.191160][Epoch 0/50] [Batch 325/1250] [D loss: 0.167744] [G loss: 0.178872][Epoch 0/50] [Batch 326/1250] [D loss: 0.080199] [G loss: 0.189942][Epoch 0/50] [Batch 327/1250] [D loss: 0.106466] [G loss: 0.188136][Epoch 0/50] [Batch 328/1250] [D loss: 0.257575] [G loss: 0.215722][Epoch 0/50] [Batch 329/1250] [D loss: 0.100497] [G loss: 0.179547][Epoch 0/50] [Batch 330/1250] [D loss: 0.232576] [G loss: 0.189295][Epoch 0/50] [Batch 331/1250] [D loss: 0.227713] [G loss: 0.275717]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 118 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 332/1250] [D loss: 0.133294] [G loss: 0.225132]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 210 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 333/1250] [D loss: 0.026209] [G loss: 0.205938][Epoch 0/50] [Batch 334/1250] [D loss: 0.042898] [G loss: 0.255394][Epoch 0/50] [Batch 335/1250] [D loss: 0.061754] [G loss: 0.173439][Epoch 0/50] [Batch 336/1250] [D loss: 0.099315] [G loss: 0.226618][Epoch 0/50] [Batch 337/1250] [D loss: 0.195442] [G loss: 0.216145][Epoch 0/50] [Batch 338/1250] [D loss: 0.199122] [G loss: 0.208991]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 112 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 339/1250] [D loss: 0.270845] [G loss: 0.265479][Epoch 0/50] [Batch 340/1250] [D loss: 0.371014] [G loss: 0.223607][Epoch 0/50] [Batch 341/1250] [D loss: 0.285471] [G loss: 0.199853][Epoch 0/50] [Batch 342/1250] [D loss: 0.194566] [G loss: 0.171566][Epoch 0/50] [Batch 343/1250] [D loss: 0.117970] [G loss: 0.213103][Epoch 0/50] [Batch 344/1250] [D loss: 0.156083] [G loss: 0.183392][Epoch 0/50] [Batch 345/1250] [D loss: 0.242831] [G loss: 0.215199][Epoch 0/50] [Batch 346/1250] [D loss: 0.126590] [G loss: 0.192943][Epoch 0/50] [Batch 347/1250] [D loss: 0.200780] [G loss: 0.224693]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 62 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 348/1250] [D loss: 0.062482] [G loss: 0.239645][Epoch 0/50] [Batch 349/1250] [D loss: 0.198785] [G loss: 0.280519][Epoch 0/50] [Batch 350/1250] [D loss: 0.026184] [G loss: 0.262256][Epoch 0/50] [Batch 351/1250] [D loss: 0.069137] [G loss: 0.238392][Epoch 0/50] [Batch 352/1250] [D loss: 0.091276] [G loss: 0.197591][Epoch 0/50] [Batch 353/1250] [D loss: 0.064278] [G loss: 0.204834][Epoch 0/50] [Batch 354/1250] [D loss: 0.011654] [G loss: 0.203145][Epoch 0/50] [Batch 355/1250] [D loss: 0.204685] [G loss: 0.250055][Epoch 0/50] [Batch 356/1250] [D loss: 0.167794] [G loss: 0.213134][Epoch 0/50] [Batch 357/1250] [D loss: 0.085868] [G loss: 0.160016][Epoch 0/50] [Batch 358/1250] [D loss: 0.122465] [G loss: 0.197262][Epoch 0/50] [Batch 359/1250] [D loss: 0.048264] [G loss: 0.227783]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 142 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 360/1250] [D loss: 0.029629] [G loss: 0.169383][Epoch 0/50] [Batch 361/1250] [D loss: 0.356432] [G loss: 0.266432][Epoch 0/50] [Batch 362/1250] [D loss: 0.152265] [G loss: 0.173332][Epoch 0/50] [Batch 363/1250] [D loss: 0.612872] [G loss: 0.182961][Epoch 0/50] [Batch 364/1250] [D loss: 0.185698] [G loss: 0.164027][Epoch 0/50] [Batch 365/1250] [D loss: 0.144044] [G loss: 0.181241]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 193 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 366/1250] [D loss: 0.163961] [G loss: 0.246935][Epoch 0/50] [Batch 367/1250] [D loss: 0.152067] [G loss: 0.187217]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 151 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 368/1250] [D loss: 0.113201] [G loss: 0.193176][Epoch 0/50] [Batch 369/1250] [D loss: 0.200293] [G loss: 0.186140][Epoch 0/50] [Batch 370/1250] [D loss: 0.217315] [G loss: 0.174721]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 76 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 371/1250] [D loss: 0.091411] [G loss: 0.205037][Epoch 0/50] [Batch 372/1250] [D loss: 0.246669] [G loss: 0.184100][Epoch 0/50] [Batch 373/1250] [D loss: 0.152634] [G loss: 0.217943]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 87 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 374/1250] [D loss: 0.121677] [G loss: 0.221993][Epoch 0/50] [Batch 375/1250] [D loss: 0.081923] [G loss: 0.248473]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 69 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 376/1250] [D loss: 0.029204] [G loss: 0.246662][Epoch 0/50] [Batch 377/1250] [D loss: 0.088353] [G loss: 0.239760][Epoch 0/50] [Batch 378/1250] [D loss: 0.029519] [G loss: 0.207014][Epoch 0/50] [Batch 379/1250] [D loss: 0.593087] [G loss: 0.213677]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 51 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 380/1250] [D loss: 0.102876] [G loss: 0.241138][Epoch 0/50] [Batch 381/1250] [D loss: 0.144041] [G loss: 0.266097]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 459 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 0/50] [Batch 382/1250] [D loss: 0.216212] [G loss: 0.168524][Epoch 0/50] [Batch 383/1250] [D loss: 0.055335] [G loss: 0.191868][Epoch 0/50] [Batch 384/1250] [D loss: 0.162814] [G loss: 0.194181][Epoch 0/50] [Batch 385/1250] [D loss: 0.417270] [G loss: 0.296278]
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 205 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# ...
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 613 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 20/50] [Batch 578/1250] [D loss: 0.000367] [G loss: 0.166755][Epoch 20/50] [Batch 579/1250] [D loss: 0.000233] [G loss: 0.228090][Epoch 20/50] [Batch 580/1250] [D loss: 0.000525] [G loss: 0.196785][Epoch 20/50] [Batch 581/1250] [D loss: 0.000308] [G loss: 0.186067][Epoch 20/50] [Batch 582/1250] [D loss: 0.000249] [G loss: 0.203796][Epoch 20/50] [Batch 583/1250] [D loss: 0.000539] [G loss: 0.223557][Epoch 20/50] [Batch 584/1250] [D loss: 0.000719] [G loss: 0.214346][Epoch 20/50] [Batch 585/1250] [D loss: 0.000671] [G loss: 0.197234][Epoch 20/50] [Batch 586/1250] [D loss: 0.000509] [G loss: 0.271251][Epoch 20/50] [Batch 587/1250] [D loss: 0.000668] [G loss: 0.183265][Epoch 20/50] [Batch 588/1250] [D loss: 0.000779] [G loss: 0.251766][Epoch 20/50] [Batch 589/1250] [D loss: 0.000739] [G loss: 0.238401][Epoch 20/50] [Batch 590/1250] [D loss: 0.000844] [G loss: 0.194366][Epoch 20/50] [Batch 591/1250] [D loss: 0.000621] [G loss: 0.245453][Epoch 20/50] [Batch 592/1250] [D loss: 0.000697] [G loss: 0.153062][Epoch 20/50] [Batch 593/1250] [D loss: 0.000743] [G loss: 0.183563][Epoch 20/50] [Batch 594/1250] [D loss: 0.000418] [G loss: 0.212603][Epoch 20/50] [Batch 595/1250] [D loss: 0.000395] [G loss: 0.224698][Epoch 20/50] [Batch 596/1250] [D loss: 0.000577] [G loss: 0.171960][Epoch 20/50] [Batch 597/1250] [D loss: 0.000853] [G loss: 0.178231][Epoch 20/50] [Batch 598/1250] [D loss: 0.000490] [G loss: 0.200173][Epoch 20/50] [Batch 599/1250] [D loss: 0.000387] [G loss: 0.200250][Epoch 20/50] [Batch 600/1250] [D loss: 0.000317] [G loss: 0.221035][Epoch 20/50] [Batch 601/1250] [D loss: 0.000344] [G loss: 0.137868][Epoch 20/50] [Batch 602/1250] [D loss: 0.000506] [G loss: 0.221944][Epoch 20/50] [Batch 603/1250] [D loss: 0.000326] [G loss: 0.183282][Epoch 20/50] [Batch 604/1250] [D loss: 0.021364] [G loss: 0.263164][Epoch 20/50] [Batch 605/1250] [D loss: 0.004596] [G loss: 0.225787][Epoch 20/50] [Batch 606/1250] [D loss: 0.004919] [G loss: 0.237578][Epoch 20/50] [Batch 607/1250] [D loss: 0.002753] [G loss: 0.192308][Epoch 20/50] [Batch 608/1250] [D loss: 0.001245] [G loss: 0.226629][Epoch 20/50] [Batch 609/1250] [D loss: 0.001014] [G loss: 0.212780][Epoch 20/50] [Batch 610/1250] [D loss: 0.001273] [G loss: 0.184863][Epoch 20/50] [Batch 611/1250] [D loss: 0.000543] [G loss: 0.214064][Epoch 20/50] [Batch 612/1250] [D loss: 0.000699] [G loss: 0.148312][Epoch 20/50] [Batch 613/1250] [D loss: 0.001635] [G loss: 0.194341][Epoch 20/50] [Batch 614/1250] [D loss: 0.001246] [G loss: 0.240232][Epoch 20/50] [Batch 615/1250] [D loss: 0.000647] [G loss: 0.179174][Epoch 20/50] [Batch 616/1250] [D loss: 0.000355] [G loss: 0.215304][Epoch 20/50] [Batch 617/1250] [D loss: 0.000388] [G loss: 0.285585][Epoch 20/50] [Batch 618/1250] [D loss: 0.000656] [G loss: 0.210666][Epoch 20/50] [Batch 619/1250] [D loss: 0.000250] [G loss: 0.251022][Epoch 20/50] [Batch 620/1250] [D loss: 0.000346] [G loss: 0.262505][Epoch 20/50] [Batch 621/1250] [D loss: 0.000388] [G loss: 0.171863][Epoch 20/50] [Batch 622/1250] [D loss: 0.000259] [G loss: 0.192800][Epoch 20/50] [Batch 623/1250] [D loss: 0.000284] [G loss: 0.256282][Epoch 20/50] [Batch 624/1250] [D loss: 0.001198] [G loss: 0.182840][Epoch 20/50] [Batch 625/1250] [D loss: 0.000872] [G loss: 0.229677][Epoch 20/50] [Batch 626/1250] [D loss: 0.002057] [G loss: 0.276060][Epoch 20/50] [Batch 627/1250] [D loss: 0.001475] [G loss: 0.183909][Epoch 20/50] [Batch 628/1250] [D loss: 0.001823] [G loss: 0.230088][Epoch 20/50] [Batch 629/1250] [D loss: 0.001221] [G loss: 0.242472][Epoch 20/50] [Batch 630/1250] [D loss: 0.000569] [G loss: 0.228283][Epoch 20/50] [Batch 631/1250] [D loss: 0.000337] [G loss: 0.179026][Epoch 20/50] [Batch 632/1250] [D loss: 0.000364] [G loss: 0.181465][Epoch 20/50] [Batch 633/1250] [D loss: 0.000284] [G loss: 0.212127][Epoch 20/50] [Batch 634/1250] [D loss: 0.000220] [G loss: 0.197307][Epoch 20/50] [Batch 635/1250] [D loss: 0.000412] [G loss: 0.173699][Epoch 20/50] [Batch 636/1250] [D loss: 0.000407] [G los ...
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 637 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 20/50] [Batch 643/1250] [D loss: 0.002150] [G loss: 0.188694][Epoch 20/50] [Batch 644/1250] [D loss: 0.000942] [G loss: 0.231983][Epoch 20/50] [Batch 645/1250] [D loss: 0.000672] [G loss: 0.293999][Epoch 20/50] [Batch 646/1250] [D loss: 0.000844] [G loss: 0.252609][Epoch 20/50] [Batch 647/1250] [D loss: 0.000625] [G loss: 0.222623][Epoch 20/50] [Batch 648/1250] [D loss: 0.001019] [G loss: 0.191119][Epoch 20/50] [Batch 649/1250] [D loss: 0.001710] [G loss: 0.206816][Epoch 20/50] [Batch 650/1250] [D loss: 0.000998] [G loss: 0.188859][Epoch 20/50] [Batch 651/1250] [D loss: 0.000607] [G loss: 0.225757][Epoch 20/50] [Batch 652/1250] [D loss: 0.000395] [G loss: 0.191878][Epoch 20/50] [Batch 653/1250] [D loss: 0.000484] [G loss: 0.244949][Epoch 20/50] [Batch 654/1250] [D loss: 0.000349] [G loss: 0.232884][Epoch 20/50] [Batch 655/1250] [D loss: 0.000268] [G loss: 0.261015][Epoch 20/50] [Batch 656/1250] [D loss: 0.000490] [G loss: 0.140910][Epoch 20/50] [Batch 657/1250] [D loss: 0.000529] [G loss: 0.193901][Epoch 20/50] [Batch 658/1250] [D loss: 0.000524] [G loss: 0.160755][Epoch 20/50] [Batch 659/1250] [D loss: 0.000430] [G loss: 0.195598][Epoch 20/50] [Batch 660/1250] [D loss: 0.000625] [G loss: 0.244307][Epoch 20/50] [Batch 661/1250] [D loss: 0.000472] [G loss: 0.213633][Epoch 20/50] [Batch 662/1250] [D loss: 0.000514] [G loss: 0.223468][Epoch 20/50] [Batch 663/1250] [D loss: 0.000417] [G loss: 0.232473][Epoch 20/50] [Batch 664/1250] [D loss: 0.000362] [G loss: 0.212549][Epoch 20/50] [Batch 665/1250] [D loss: 0.000673] [G loss: 0.280110][Epoch 20/50] [Batch 666/1250] [D loss: 0.000582] [G loss: 0.247610][Epoch 20/50] [Batch 667/1250] [D loss: 0.000522] [G loss: 0.203276][Epoch 20/50] [Batch 668/1250] [D loss: 0.001153] [G loss: 0.177213][Epoch 20/50] [Batch 669/1250] [D loss: 0.001130] [G loss: 0.209710][Epoch 20/50] [Batch 670/1250] [D loss: 0.001288] [G loss: 0.209887][Epoch 20/50] [Batch 671/1250] [D loss: 0.000528] [G loss: 0.234071][Epoch 20/50] [Batch 672/1250] [D loss: 0.000402] [G loss: 0.184639][Epoch 20/50] [Batch 673/1250] [D loss: 0.000416] [G loss: 0.275949][Epoch 20/50] [Batch 674/1250] [D loss: 0.000225] [G loss: 0.223049][Epoch 20/50] [Batch 675/1250] [D loss: 0.000523] [G loss: 0.182637][Epoch 20/50] [Batch 676/1250] [D loss: 0.000175] [G loss: 0.223118][Epoch 20/50] [Batch 677/1250] [D loss: 0.000673] [G loss: 0.216282][Epoch 20/50] [Batch 678/1250] [D loss: 0.000635] [G loss: 0.195281][Epoch 20/50] [Batch 679/1250] [D loss: 0.000933] [G loss: 0.203690][Epoch 20/50] [Batch 680/1250] [D loss: 0.001053] [G loss: 0.186000][Epoch 20/50] [Batch 681/1250] [D loss: 0.000475] [G loss: 0.247560][Epoch 20/50] [Batch 682/1250] [D loss: 0.001318] [G loss: 0.138607][Epoch 20/50] [Batch 683/1250] [D loss: 0.001392] [G loss: 0.228377][Epoch 20/50] [Batch 684/1250] [D loss: 0.001611] [G loss: 0.186679][Epoch 20/50] [Batch 685/1250] [D loss: 0.002248] [G loss: 0.176560][Epoch 20/50] [Batch 686/1250] [D loss: 0.002174] [G loss: 0.207002][Epoch 20/50] [Batch 687/1250] [D loss: 0.001342] [G loss: 0.234663][Epoch 20/50] [Batch 688/1250] [D loss: 0.000486] [G loss: 0.243739][Epoch 20/50] [Batch 689/1250] [D loss: 0.000666] [G loss: 0.168728][Epoch 20/50] [Batch 690/1250] [D loss: 0.001133] [G loss: 0.218881][Epoch 20/50] [Batch 691/1250] [D loss: 0.001081] [G loss: 0.233418][Epoch 20/50] [Batch 692/1250] [D loss: 0.000443] [G loss: 0.236715][Epoch 20/50] [Batch 693/1250] [D loss: 0.000347] [G loss: 0.233097][Epoch 20/50] [Batch 694/1250] [D loss: 0.000510] [G loss: 0.233205][Epoch 20/50] [Batch 695/1250] [D loss: 0.000784] [G loss: 0.214145][Epoch 20/50] [Batch 696/1250] [D loss: 0.000894] [G loss: 0.210191][Epoch 20/50] [Batch 697/1250] [D loss: 0.000696] [G loss: 0.218906][Epoch 20/50] [Batch 698/1250] [D loss: 0.000629] [G loss: 0.201566][Epoch 20/50] [Batch 699/1250] [D loss: 0.000735] [G loss: 0.237942][Epoch 20/50] [Batch 700/1250] [D loss: 0.000711] [G loss: 0.244699][Epoch 20/50] [Batch 701/1250] [D loss: 0.000642] [G los ...
# /opt/conda/lib/python3.7/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 1177 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# [Epoch 20/50] [Batch 706/1250] [D loss: 0.001529] [G loss: 0.228673][Epoch 20/50] [Batch 707/1250] [D loss: 0.001032] [G loss: 0.205066][Epoch 20/50] [Batch 708/1250] [D loss: 0.000515] [G loss: 0.196372][Epoch 20/50] [Batch 709/1250] [D loss: 0.000425] [G loss: 0.260872][Epoch 20/50] [Batch 710/1250] [D loss: 0.000702] [G loss: 0.200434][Epoch 20/50] [Batch 711/1250] [D loss: 0.000618] [G loss: 0.190249][Epoch 20/50] [Batch 712/1250] [D loss: 0.000177] [G loss: 0.211585][Epoch 20/50] [Batch 713/1250] [D loss: 0.000399] [G loss: 0.175453][Epoch 20/50] [Batch 714/1250] [D loss: 0.000339] [G loss: 0.193576][Epoch 20/50] [Batch 715/1250] [D loss: 0.000381] [G loss: 0.211518][Epoch 20/50] [Batch 716/1250] [D loss: 0.000797] [G loss: 0.321604][Epoch 20/50] [Batch 717/1250] [D loss: 0.000328] [G loss: 0.260288][Epoch 20/50] [Batch 718/1250] [D loss: 0.000729] [G loss: 0.172928][Epoch 20/50] [Batch 719/1250] [D loss: 0.001021] [G loss: 0.171746][Epoch 20/50] [Batch 720/1250] [D loss: 0.001312] [G loss: 0.175434][Epoch 20/50] [Batch 721/1250] [D loss: 0.001137] [G loss: 0.226629][Epoch 20/50] [Batch 722/1250] [D loss: 0.001193] [G loss: 0.245380][Epoch 20/50] [Batch 723/1250] [D loss: 0.000561] [G loss: 0.262460][Epoch 20/50] [Batch 724/1250] [D loss: 0.000485] [G loss: 0.232635][Epoch 20/50] [Batch 725/1250] [D loss: 0.000381] [G loss: 0.273836][Epoch 20/50] [Batch 726/1250] [D loss: 0.000364] [G loss: 0.178652][Epoch 20/50] [Batch 727/1250] [D loss: 0.000425] [G loss: 0.255915][Epoch 20/50] [Batch 728/1250] [D loss: 0.000785] [G loss: 0.250651][Epoch 20/50] [Batch 729/1250] [D loss: 0.001270] [G loss: 0.249874][Epoch 20/50] [Batch 730/1250] [D loss: 0.000857] [G loss: 0.224165][Epoch 20/50] [Batch 731/1250] [D loss: 0.000509] [G loss: 0.182746][Epoch 20/50] [Batch 732/1250] [D loss: 0.000491] [G loss: 0.271382][Epoch 20/50] [Batch 733/1250] [D loss: 0.000577] [G loss: 0.198392][Epoch 20/50] [Batch 734/1250] [D loss: 0.000800] [G loss: 0.177889][Epoch 20/50] [Batch 735/1250] [D loss: 0.000552] [G loss: 0.265864][Epoch 20/50] [Batch 736/1250] [D loss: 0.000199] [G loss: 0.219361][Epoch 20/50] [Batch 737/1250] [D loss: 0.000329] [G loss: 0.230540][Epoch 20/50] [Batch 738/1250] [D loss: 0.000558] [G loss: 0.210315][Epoch 20/50] [Batch 739/1250] [D loss: 0.000376] [G loss: 0.191596][Epoch 20/50] [Batch 740/1250] [D loss: 0.000250] [G loss: 0.209085][Epoch 20/50] [Batch 741/1250] [D loss: 0.000317] [G loss: 0.305271][Epoch 20/50] [Batch 742/1250] [D loss: 0.000428] [G loss: 0.191009][Epoch 20/50] [Batch 743/1250] [D loss: 0.000373] [G loss: 0.195489][Epoch 20/50] [Batch 744/1250] [D loss: 0.000176] [G loss: 0.209604][Epoch 20/50] [Batch 745/1250] [D loss: 0.001146] [G loss: 0.275418][Epoch 20/50] [Batch 746/1250] [D loss: 0.000943] [G loss: 0.243389][Epoch 20/50] [Batch 747/1250] [D loss: 0.000636] [G loss: 0.223761][Epoch 20/50] [Batch 748/1250] [D loss: 0.000536] [G loss: 0.261116][Epoch 20/50] [Batch 749/1250] [D loss: 0.000297] [G loss: 0.241803][Epoch 20/50] [Batch 750/1250] [D loss: 0.000218] [G loss: 0.198674][Epoch 20/50] [Batch 751/1250] [D loss: 0.000478] [G loss: 0.166118][Epoch 20/50] [Batch 752/1250] [D loss: 0.000352] [G loss: 0.203214][Epoch 20/50] [Batch 753/1250] [D loss: 0.000625] [G loss: 0.270493][Epoch 20/50] [Batch 754/1250] [D loss: 0.000973] [G loss: 0.197276][Epoch 20/50] [Batch 755/1250] [D loss: 0.000928] [G loss: 0.245500][Epoch 20/50] [Batch 756/1250] [D loss: 0.000721] [G loss: 0.239139][Epoch 20/50] [Batch 757/1250] [D loss: 0.000593] [G loss: 0.218622][Epoch 20/50] [Batch 758/1250] [D loss: 0.001456] [G loss: 0.203607][Epoch 20/50] [Batch 759/1250] [D loss: 0.000690] [G loss: 0.215628][Epoch 20/50] [Batch 760/1250] [D loss: 0.000465] [G loss: 0.240671][Epoch 20/50] [Batch 761/1250] [D loss: 0.000776] [G loss: 0.179210][Epoch 20/50] [Batch 762/1250] [D loss: 0.000650] [G loss: 0.170353][Epoch 20/50] [Batch 763/1250] [D loss: 0.000355] [G loss: 0.208740][Epoch 20/50] [Batch 764/1250] [D loss: 0.001069] [G los ...
